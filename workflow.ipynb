# %% [markdown]
# # Linear Distribution Optimal Power Flow (LinDistFlow)
#
# This research is to meant to demonstrate the OEDI SI use case for distributed optimal power flow (DOPF). The goal was to formulate the optimal power flow problem in the distribution system for active and reactive power setpoints of PV systems using topology information and voltage measurements. The co-simulation runs every 15 minutes as outlined within the scenario file for the given feeder configuration.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
from oedisi.componentframework import wiring_diagram_utils
from post_process import plotter

ROOT = os.getcwd()
OUTPUTS = f"{ROOT}/outputs"
SCENARIO_DIR, SCENARIOS, _ = next(os.walk(f'{ROOT}/scenario/'))

print(SCENARIO_DIR)
for idx, scenario in enumerate(SCENARIOS):
    print(idx, scenario)
# Out:
# /home/tylor/dev/oedisi_dopf/scenario/
# 0 medium_extreme
# 1 large
# 2 medium_high
# 3 omoo
# 4 medium
# 5 omoo_medium
# 6 omoo_medium_extreme
# 7 medium_low
# 8 small_low
# 9 small
# 10 small_medium
# 11 small_high
# 12 small_extreme
# 13 ieee123
# 14 medium_medium
# 15 omoo_small

# %% [markdown]
# ## Select a scenario
# Set the SCENARIOS index value from the available scenarios

# %%
index = 2
SCENARIO = SCENARIOS[index]

path = f"{SCENARIO_DIR}{SCENARIO}"
with open(f"{path}/system.json") as f:
    wiring_diagram = wiring_diagram_utils.WiringDiagram.parse_obj(json.load(f))

wiring_diagram_utils.plot_graph_matplotlib(wiring_diagram)

# %% [markdown]
# ## Build the selected scenario
# The build will create a new build_<scenario> folder and copy over the federate files as specified. Assume successful build if no errors are presented.

# %%
os.system(f"oedisi build --system {path}/system.json --component-dict {path}/components.json --target-directory build_{SCENARIO}")
# Out:
# Loading the components defined in /home/tylor/dev/oedisi_dopf/scenario/medium_high/components.json
# Loading system json /home/tylor/dev/oedisi_dopf/scenario/medium_high/system.json
# Building system in build_medium_high
# 0

# %% [markdown]
# ## Run selected scenario
# The simulation will take 5-30 minutes to run depending on the scenario. The results will print Done once complete.

# %%
os.system("pkill -9 helics_broker")
os.system(f"oedisi run --runner build_{SCENARIO}/system_runner.json")
# Out:
# [warn] helics-cli's web interface is not installed. You may want to run `pip install "helics[cli]"`.
# [warn] helics-cli's observer functionality is not installed. You may want to run `pip install "helics[cli]"`.
# [info] Running federation: medium_high
# [info] Running federate recorder_power_real as a background process
# [info] Running federate recorder_power_imag as a background process
# [info] Running federate recorder_voltage_real as a background process
# [info] Running federate recorder_voltage_imag as a background process
# [info] Running federate recorder_voltage_magnitude as a background process
# [info] Running federate recorder_opf_voltage_magnitude as a background process
# [info] Running federate recorder_delta_setpoint as a background process
# [info] Running federate recorder_forecast_curtail as a background process
# [info] Running federate recorder_real_curtail as a background process
# [info] Running federate feeder as a background process
# [info] Running federate lindistflow as a background process
# [info] Running federate broker as a background process
# [info] Waiting for 12 processes to finish ...
# [error] Process recorder_power_real has failed, killing other processes
# [error] Process recorder_power_real exited with return code 1
# [warn] Last 10 lines of recorder_power_real.log:
# ...
# [2024-07-03 10:31:12.666] [console] [error] commERROR||recorder_power_real (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23495
# [2024-07-03 10:31:12.666] [console] [error] commERROR||recorder_power_real (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_power_real/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_power_real/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_power_imag exited with return code 1
# [warn] Last 10 lines of recorder_power_imag.log:
# ...
# [2024-07-03 10:31:12.671] [console] [error] commERROR||recorder_power_imag (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23498
# [2024-07-03 10:31:12.671] [console] [error] commERROR||recorder_power_imag (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_power_imag/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_power_imag/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_voltage_real exited with return code 1
# [warn] Last 10 lines of recorder_voltage_real.log:
# ...
# [2024-07-03 10:31:12.654] [console] [error] commERROR||recorder_voltage_real (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23493
# [2024-07-03 10:31:12.654] [console] [error] commERROR||recorder_voltage_real (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_real/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_real/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_voltage_imag exited with return code 1
# [warn] Last 10 lines of recorder_voltage_imag.log:
# ...
# [2024-07-03 10:31:12.636] [console] [error] commERROR||recorder_voltage_imag (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23492
# [2024-07-03 10:31:12.636] [console] [error] commERROR||recorder_voltage_imag (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_imag/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_imag/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_voltage_magnitude exited with return code 1
# [warn] Last 10 lines of recorder_voltage_magnitude.log:
# ...
# [2024-07-03 10:31:12.661] [console] [error] commERROR||recorder_voltage_magnitude (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23494
# [2024-07-03 10:31:12.661] [console] [error] commERROR||recorder_voltage_magnitude (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_magnitude/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_voltage_magnitude/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_opf_voltage_magnitude exited with return code 1
# [warn] Last 10 lines of recorder_opf_voltage_magnitude.log:
# ...
# [2024-07-03 10:31:12.670] [console] [error] commERROR||recorder_opf_voltage_magnitude (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23497
# [2024-07-03 10:31:12.670] [console] [error] commERROR||recorder_opf_voltage_magnitude (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_opf_voltage_magnitude/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_opf_voltage_magnitude/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_delta_setpoint exited with return code 1
# [warn] Last 10 lines of recorder_delta_setpoint.log:
# ...
# [2024-07-03 10:31:12.667] [console] [error] commERROR||recorder_delta_setpoint (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23496
# [2024-07-03 10:31:12.667] [console] [error] commERROR||recorder_delta_setpoint (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_delta_setpoint/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_delta_setpoint/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_forecast_curtail exited with return code 1
# [warn] Last 10 lines of recorder_forecast_curtail.log:
# ...
# [2024-07-03 10:31:12.680] [console] [error] commERROR||recorder_forecast_curtail (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23500
# [2024-07-03 10:31:12.680] [console] [error] commERROR||recorder_forecast_curtail (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_forecast_curtail/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_forecast_curtail/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process recorder_real_curtail exited with return code 1
# [warn] Last 10 lines of recorder_real_curtail.log:
# ...
# [2024-07-03 10:31:12.680] [console] [error] commERROR||recorder_real_curtail (0)[connecting]::Unable to bind zmq pull socket giving up tcp://127.0.0.1:23499
# [2024-07-03 10:31:12.680] [console] [error] commERROR||recorder_real_curtail (0)[connecting]::receiver connection failure
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_real_curtail/record.py", line 113, in <module>
#     sfed = Recorder(name, feather_path, csv_path, input_mapping)
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/recorder_real_curtail/record.py", line 35, in __init__
#     self.vfed = h.helicsCreateValueFederate(name, fedinfo)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [error] Process lindistflow exited with return code 1
# [warn] Last 10 lines of lindistflow.log:
# ...
# Traceback (most recent call last):
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/lindistflow/opf_federate.py", line 316, in <module>
#     fed = OPFFederate()
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/lindistflow/opf_federate.py", line 51, in __init__
#     self.initilize()
#   File "/home/tylor/dev/oedisi_dopf/build_medium_high/lindistflow/opf_federate.py", line 88, in initilize
#     self.fed = h.helicsCreateValueFederate(self.static.name, self.info)
#   File "/home/tylor/dev/oedisi_dopf/.venv/lib/python3.10/site-packages/helics/capi.py", line 3615, in helicsCreateValueFederate
#     raise HelicsException("[" + str(err.error_code) + "] " + ffi.string(err.message).decode())
# helics.capi.HelicsException: [-1] Unable to connect to broker->unable to register federate
# ...
# [info] Done.
# 0

# %% [markdown]
# ## Plot data

# %%
if SCENARIO == "ieee123":
    root = "150"
    seperator = "    "
    coordsys = "2D"
    annotate = True
    ymin = 0.98
    ymax = 1.06
    alg = "LinDistFlow"

elif SCENARIO in ["small", "small_low", "small_medium", "small_high", "small_extreme"]:
    root = "P1UDT942-P1UHS0_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.02
    ymax = 1.035
    alg = "LinDistFlow"

elif SCENARIO in ["medium", "medium_low", "medium_medium", "medium_high", "medium_extreme"]:
    root = "P6UDT5293-P6UHS10_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.01
    ymax = 1.05
    alg = "LinDistFlow"

elif SCENARIO == "medium_extreme":
    root = "P6UDT5293-P6UHS10_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.01
    ymax = 1.05
    alg = "LinDistFlow"

elif SCENARIO == "omoo_medium_extreme":
    root = "P6UDT5293-P6UHS10_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.01
    ymax = 1.05
    alg = "LinDistFlow"

elif SCENARIO == "omoo":
    root = "150"
    seperator = "    "
    coordsys = "2D"
    annotate = True
    ymin = 0.98
    ymax = 1.06
    alg = "OMOO"

elif SCENARIO == "omoo_small":
    root = "P1UDT942-P1UHS0_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.02
    ymax = 1.035
    alg = "OMOO"

elif SCENARIO == "omoo_medium":
    root = "P6UDT5293-P6UHS10_1247X"
    seperator = " "
    coordsys = "GEO"
    annotate = False
    ymin = 1.01
    ymax = 1.05
    alg = "OMOO"

else:
    print(f"{SCENARIO} not found")

# Directory location
directory = f"{OUTPUTS}/{SCENARIO}"
topology_filepath = os.path.join(directory, "topology.json")
buscoord_filepath = os.path.join(directory, "BusCoords.dat")
real_voltage_filepath = os.path.join(directory, "voltage_real.feather")
imag_voltage_filepath = os.path.join(directory, "voltage_imag.feather")
opf_voltage_filepath = os.path.join(directory, "opf_voltage_mag.feather")
real_curtail_filepath = os.path.join(directory, "real_curtail.feather")
forecast_curtail_filepath = os.path.join(directory, "forecast_curtail.feather")
time=["07:30", "12:30", "15:30"]

# %%
fig_filename = os.path.join(directory, f"network.png")
plotter.plot_network(
    topology_filepath,
    buscoord_filepath,
    real_voltage_filepath,
    imag_voltage_filepath,
    root_node=root, sep=seperator,
    time=time, node_size=50,
    show=True, to_file=fig_filename,
    suptitle_sfx=f"({alg} Algorithm)",
)

# %%
fig_filename = os.path.join(directory, f"vtree.png")
plotter.plot_voltage_tree(
    topology_filepath,
    buscoord_filepath,
    real_voltage_filepath,
    imag_voltage_filepath,
    root_node=root,
    sep=seperator,
    time=time,
    show=True, to_file=fig_filename,
    lw=2.5, ls='dashed',
    figsize=(60, 15),
    annotate=annotate,
    suptitle_sfx=f"({alg} Algorithm)",
    coordsys=coordsys,
    ymin=ymin, ymax=ymax,
)

# %%
fig_filename = os.path.join(directory, f"voltage_comparison.png")
plotter.plot_opf_voltage_comparison(
    topology_filepath,
    real_voltage_filepath, 
    imag_voltage_filepath, 
    opf_voltage_filepath,
    time=time,
    show=True
)

# %%
plotter.plot_curtail(real_curtail_filepath, suptitle_pfx="Real ")

# %%
plotter.plot_curtail(forecast_curtail_filepath, suptitle_pfx="Forecasted ")
